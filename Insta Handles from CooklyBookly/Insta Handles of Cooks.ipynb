# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5287e84cca71> in <module>
#       1 import pandas as pd
#       2 from bs4 import BeautifulSoup
# ----> 3 from selenium import webdriver
#       4 from webdriver_manager.chrome import ChromeDriverManager
#       5 import time
#
# ModuleNotFoundError: No module named 'selenium'

# %%
options = webdriver.ChromeOptions()

options.add_argument("--incognito")
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://cooklybookly.com/authors?offset=0&limit=12")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0e1fa9513599> in <module>
# ----> 1 options = webdriver.ChromeOptions()
#       2
#       3 options.add_argument("--incognito")
#       4 driver = webdriver.Chrome(ChromeDriverManager().install())
#       5 driver.get("https://cooklybookly.com/authors?offset=0&limit=12")
#
# NameError: name 'webdriver' is not defined

# %%
src = driver.page_source
soup=BeautifulSoup(src)

# %%
# sc-llYSUQ kodFKt MuiPaper-root MuiPaper-elevation MuiPaper-elevation16 sc-eJwWfJ 
# jaxMzl MuiDrawer-paper MuiDrawer-paperAnchorRight

# sc-llYSUQ kodFKt MuiPaper-root MuiPaper-elevation MuiPaper-elevation16 sc-eJwWfJ jaxMzl 
# MuiDrawer-paper MuiDrawer-paperAnchorRight

# %%
modals = soup.find_all('a', attrs = {'class' : 'jss165'})
modals
# Out:
# [<a class="jss165" href="/jonwatts88">@jonwatts88</a>,
#  <a class="jss165" href="/ellie.eatseverything">@ellie.eatseverything</a>,
#  <a class="jss165" href="/recipebreakout">@recipebreakout</a>,
#  <a class="jss165" href="/papamikeskitchen">@papamikeskitchen</a>,
#  <a class="jss165" href="/zenaskitchen">@zenaskitchen</a>,
#  <a class="jss165" href="/thefoodiefootballer">@thefoodiefootballer</a>,
#  <a class="jss165" href="/date_night_dishes">@date_night_dishes</a>,
#  <a class="jss165" href="/cheese.and.han">@cheese.and.han</a>,
#  <a class="jss165" href="/cookwithjopratt">@cookwithjopratt</a>,
#  <a class="jss165" href="/janecdevonshire">@janecdevonshire</a>,
#  <a class="jss165" href="/zarskitchen">@zarskitchen</a>,
#  <a class="jss165" href="/famdelites">@famdelites</a>,
#  <a class="jss165" href="/homecookgeek">@homecookgeek</a>,
#  <a class="jss165" href="/gabriellas_kitchen">@gabriellas_kitchen</a>,
#  <a class="jss165" href="/toon_adough">@toon_adough</a>,
# ...

# %%
profiles = []
for i in range(len(modals)):
    profiles.append(modals[i].text.strip())
profiles
# Out:
# ['@jonwatts88',
#  '@ellie.eatseverything',
#  '@recipebreakout',
#  '@papamikeskitchen',
#  '@zenaskitchen',
#  '@thefoodiefootballer',
#  '@date_night_dishes',
#  '@cheese.and.han',
#  '@cookwithjopratt',
#  '@janecdevonshire',
#  '@zarskitchen',
#  '@famdelites',
#  '@homecookgeek',
#  '@gabriellas_kitchen',
#  '@toon_adough',
#  '@fiona_dawson',
#  '@sanjcooks',
#  '@southcoast_kitchen',
#  '@nicolevittoria',
#  '@whipupastorm',
#  '@foodiegeektrish',
#  '@mcr.foodie',
#  '@fatmowcooking',
#  '@sandeep_cooks',
#  '@chefromainavril',
#  '@dolly_olly_oxenfree',
#  '@ashcamsmith',
#  '@healthyfitbella',
#  '@cooklybooklyhq',
#  '@familyhomecook',
#  '@adrianapaolella',
#  '@lovetocook4ppl',
#  '@nicola_family_kitchen',
#  '@imtheonewhocooks',
#  '@keithcooks_',
#  '@cheflwilz',
#  '@hungrygirlintoronto',
#  '@cotswolds_cuisine',
#  '@ravenousfox',
#  '@deanedwardschef',
#  '@vernahungrybanana',
#  '@jojo_louise_sw',
#  '@the_goodegg_',
#  '@sincerelyaline',
#  '@lululemonandlace',
# ...

# %%
handles = ['@jonwatts88',
 '@ellie.eatseverything',
 '@recipebreakout',
 '@papamikeskitchen',
 '@zenaskitchen',
 '@thefoodiefootballer',
 '@date_night_dishes',
 '@cheese.and.han',
 '@cookwithjopratt',
 '@janecdevonshire',
 '@zarskitchen',
 '@famdelites',
 '@homecookgeek',
 '@gabriellas_kitchen',
 '@toon_adough',
 '@fiona_dawson',
 '@sanjcooks',
 '@southcoast_kitchen',
 '@nicolevittoria',
 '@whipupastorm',
 '@foodiegeektrish',
 '@mcr.foodie',
 '@fatmowcooking',
 '@sandeep_cooks',
 '@chefromainavril',
 '@dolly_olly_oxenfree',
 '@ashcamsmith',
 '@healthyfitbella',
 '@cooklybooklyhq',
 '@familyhomecook',
 '@adrianapaolella',
 '@lovetocook4ppl',
 '@nicola_family_kitchen',
 '@imtheonewhocooks',
 '@keithcooks_',
 '@cheflwilz',
 '@hungrygirlintoronto',
 '@cotswolds_cuisine',
 '@ravenousfox',
 '@deanedwardschef',
 '@vernahungrybanana',
 '@jojo_louise_sw',
 '@the_goodegg_',
 '@sincerelyaline',
 '@lululemonandlace',
 '@nimitacooks',
 '@jemmawatts',
 '@chefbenchurchill',
 '@sashacakeschicago',
 '@toonfatladies',
 '@spencooks',
 '@synabunoats',
 '@bristolianfoodie',
 '@amateur_amateurish_cook',
 '@ashleysbowl',
 '@veggiediaryyy',
 '@eatsleepx',
 '@eatwithstef',
 '@betheatsathome',
 '@myfoodjen',
 '@nimitacooks',
 '@season_to_taste',
 '@foodatno4',
 '@theduskyfoodie',
 '@gayatrisingh',
 '@farehamfoodie',
 '@thechinesefoodie',
 '@foodieroomie',
 '@itsinthebag',
 '@kceatsin',
 '@letseatwild',
 '@garlips',
 '@foodbyjackk',
 '@howhungry',
 '@judgefoodie_',
 '@chefnormanmusa',
 '@purely_healthy_living',
 '@omega.eats',
 '@royalfoodieofrajasthan',
 '@hecooksshesnaps',
 '@lockdowncuisine_',
 '@hungrylittlebears',
 '@eating.with.emma',
 '@emi.eats',
 '@lilofoodie',
 '@mahaliandco',
 '@soothed.by.food',
 '@grillfun',
 '@thisjewcanque',
 '@misshangry',
 '@thestdntchef',
 '@colincreates',
 '@kezscran',
 '@eatyourselfgreek',
 '@our_cookingjourney',
 '@chefcynthialouise',
 '@bigdaddyfoodie',
 '@food_with_george',
 '@eatwithruss',
 '@finefoodswithfinewax',
 '@absolutelyjodes',
 '@anjuladevi',
 '@caldesi',
 '@nathanoutlaw',
 '@sophbradshaw',
 '@spicyprawnxx',
 '@girleatsin',
 '@foster_food',
 '@scarlettvfit',
 '@food.brb',
 '@eatwithxavier',
 '@_foodislifeandlove_',
 '@pingcoombes',
 '@bboxfood',
 '@windsor__foodie',
 '@betterfoodguru',
 '@foodiefrancis',
 '@parisvegantouch',
 '@sophieglass',
 '@cleireny',
 '@thehangryblonde',
 '@brunchinpairs',
 '@theinsidebite',
 '@pleasing.palates',
 '@sarahingram1',
 '@turnerandgeorge',
 '@scrummytummies',
 '@littlechefizzy',
 '@3bfred',
 '@blackgarlicco',
 '@eatlikeafoodie',
 '@pettyelliottskitchen',
 '@s4shan',
 '@myraphasma',
 '@mrs_durbridge_home',
 '@gemsfood2020',
 '@livthepositivefooodie',
 '@recipeasy',
 '@sarchakra',
 '@allthepiglets',
 '@kim.skitchen',
 '@kouturekitchens',
 '@gate58',
 '@mymoonlightingkitchen',
 '@its.chloeh',
 '@cassidyrrrose',
 '@vickilovesfood',
 '@chischomps',
 '@cuminculture',
 '@olivier',
 '@jonshomekitchen',
 '@jamesthefoodiedad',
 '@baking_mommy_by_amal',
 '@jackieajewski',
 '@thepaulgood',
 '@cookingbymeg',
 '@thegkchef',
 '@_emmaeatsss',
 '@weightlosswithmaisie',
 '@knife.fork.spoon.',
 '@all_the_worlds_a_plate',
 '@cookwiththeheart',
 '@thegourmetdoctor',
 '@cookingella',
 '@takeawaysecret',
 '@sdscooks',
 '@love.food.sa',
 '@richardeats_',
 '@bakefour',
 '@bensondinner',
 '@kimberlyslimmingjourney',
 '@arisas_tiny_baking_world',
 '@tobycooks',
 '@yo.itz.phoebe',
 '@mazaingarm',
 '@meallionheir',
 '@likeamicrobecowboy',
 '@counting_zacros',
 '@tatycraves',
 '@garythebbqchef',
 '@greedymizdee',
 '@tbfood',
 '@deliverdeli',
 '@lovergrlh',
 '@urbnherd',
 '@forcocktailsake',
 '@monicageller',
 '@the.ambrosia.co',
 '@mattsslimming_food',
 '@charlixa',
 '@dorasfoodjourney',
 '@eliza',
 '@thelittlelifeofshazzap',
 '@foodyoulovetosee',
 '@darrenpurchese',
 '@thechristianmiller',
 '@makingismymedicine',
 '@clodagh_mckenna',
 '@ausrusslandmitliebe',
 '@divachef412',
 '@fmaythemes',
 '@thoseblissfulbites',
 '@thearianefrydman',
 '@cookingwithsaman',
 '@stacyz',
 '@miggylovesfood',
 '@whatmattmakes',
 '@evolvehealth',
 '@leeshandlemons',
 '@khyatipandey',
 '@sineyrecipes',
 '@thestarvingdaughter',
 '@chefwcj',
 '@sophxbakes',
 '@jerishomekitchen',
 '@authentic_punjabee',
 '@the_londondiary',
 '@sprockeatsvegan',
 '@palateculinaryacademy',
 '@teethatcooks',
 '@chefsinshirts',
 '@freddycb',
 '@buffetthevampireslayer',
 '@indianblondeefood',
 '@ourhouseofmunch',
 '@dinner_with_b',
 '@kuruviskitchentrails',
 '@frankiemccay',
 '@nuttyasafruitcakebakes',
 '@hannahs.plates',
 '@fedbyred',
 '@icookasia',
 '@liunova',
 '@thewobblychef',
 '@padronstreetfood',
 '@joeskitchen',
 '@the.lockdown.chef',
 '@charlottekidd.eats',
 '@alexkitchen',
 '@arimichaelides',
 '@mia',
 '@livbyfood',
 '@lauriesfoodanddrink',
 '@healthwithhannahdiane',
 '@ellicesplates',
 '@goodfoodtales',
 '@veg_foodaholic',
 '@afrodyeteskitchen',
 '@nataliethedestroyer',
 '@abril_tasteofmexico',
 '@simplybyjimmy',
 '@morethanbadcompany',
 '@mozaalwari',
 '@arenaofdream',
 '@palette_611',
 '@lililoveseating',
 '@yorkshirehomecook',
 '@foodbycourts',
 '@sliceofgourmet',
 '@blewsfoods',
 '@chefmrandmrs',
 '@tumrieats',
 '@anythoughts',
 '@oliverkercher',
 '@theantwerpkitchen',
 '@aussiechefdino',
 '@adamdixonfood',
 '@emilychaston',
 '@harrythorncooks',
 '@texykitchen',
 '@janeyfoodlover',
 '@comedinewithchloe',
 '@stabile_seitanlage',
 '@lifediethealth',
 '@happyfoodhealer',
 '@brieandmozzarella',
 '@nathchefandfitness',
 '@savannasfood',
 '@feastwithfoxy',
 '@cookinwithmalika',
 '@dulcisinfundo',
 '@cookingcurve',
 '@yummyfoodwithife',
 '@currysmoodles',
 '@in.my.bowl',
 '@tabithas.kitchen',
 '@kyladjamila',
 '@kingseatanddrink',
 '@thebruisedfrypan',
 '@knifeandsoul',
 '@healthwithchi',
 '@elterrible',
 '@veganveggieview',
 '@frin',
 '@nathparrychef',
 '@in_cucinacon_sofia',
 '@veganbyholly',
 '@more_grub',
 '@gourmetmusafir',
 '@spurweezy',
 '@cookinginmyzone',
 '@owen.cooks.eats',
 '@justamanwholikesfood',
 '@thenakedblondie',
 '@nyc_to_london',
 '@adannaya13542',
 '@asliceofparadise',
 '@kristinas_culinary',
 '@foodbynatasha_',
 '@lifeispeachy',
 '@pastry_chef_rynn',
 '@medinaroseskitchen',
 '@raqsflavours',
 '@chillijoncarne',
 '@faithlsp',
 '@dine_by_sarah',
 '@iamjoginder',
 '@dorangyn',
 '@just_beingjules',
 '@cj_karlsson',
 '@cookingwithanadi',
 '@foodymandy',
 '@mrslovegoodfood',
 '@goodeatsmanc',
 '@foodandpug_',
 '@northerngirleats',
 '@foodtravelplanet',
 '@gabisgoodiess',
 '@thefoodspotss',
 '@grubwithgriff',
 '@deepfriedbread',
 '@travelfondu',
 '@hawaeatss',
 '@makingameal',
 '@stopnchaat',
 '@meatthecook',
 '@jademakesfood',
 '@italianfamilykitchen',
 '@foodworthcelebrating',
 '@chefpaulbrown',
 '@nezumouse',
 '@elleofataste',
 '@asmitabd',
 '@onlaurasplate',
 '@teddys_plate',
 '@feast_street',
 '@thatisdelish',
 '@cravensince92',
 '@corianderandlime_',
 '@inaraa_yoga',
 '@alicooksfood',
 '@wheresthefoodfran',
 '@eatinwitheva',
 '@thebakingbuddha1',
 '@millennial_menu_',
 '@homemadesauce__',
 '@www.thehealthyworks.com',
 '@emmawattsfordinner',
 '@srilankanepicure',
 '@feedingthefridgeraiders',
 '@ladysookiechae',
 '@chefgarywolfguiney',
 '@whatbecbakes',
 '@themrskathsymes',
 '@walkingonglitterandsunshine',
 '@chefandhismrs',
 '@elfoodielife',
 '@daveyhall',
 '@kalioreximelbourne',
 '@thedewijones',
 '@highproofpreacher',
 '@barprints',
 '@mousetrapbites',
 '@thelondonappetite',
 '@sarahs_everyday_living',
 '@thehungryseed',
 '@twolittlesandwhiches',
 '@ellacartefood',
 '@sophiehyam',
 '@supercooker']
handles
# Out:
# ['@jonwatts88',
#  '@ellie.eatseverything',
#  '@recipebreakout',
#  '@papamikeskitchen',
#  '@zenaskitchen',
#  '@thefoodiefootballer',
#  '@date_night_dishes',
#  '@cheese.and.han',
#  '@cookwithjopratt',
#  '@janecdevonshire',
#  '@zarskitchen',
#  '@famdelites',
#  '@homecookgeek',
#  '@gabriellas_kitchen',
#  '@toon_adough',
#  '@fiona_dawson',
#  '@sanjcooks',
#  '@southcoast_kitchen',
#  '@nicolevittoria',
#  '@whipupastorm',
#  '@foodiegeektrish',
#  '@mcr.foodie',
#  '@fatmowcooking',
#  '@sandeep_cooks',
#  '@chefromainavril',
#  '@dolly_olly_oxenfree',
#  '@ashcamsmith',
#  '@healthyfitbella',
#  '@cooklybooklyhq',
#  '@familyhomecook',
#  '@adrianapaolella',
#  '@lovetocook4ppl',
#  '@nicola_family_kitchen',
#  '@imtheonewhocooks',
#  '@keithcooks_',
#  '@cheflwilz',
#  '@hungrygirlintoronto',
#  '@cotswolds_cuisine',
#  '@ravenousfox',
#  '@deanedwardschef',
#  '@vernahungrybanana',
#  '@jojo_louise_sw',
#  '@the_goodegg_',
#  '@sincerelyaline',
#  '@lululemonandlace',
# ...

# %%
df = pd.DataFrame({'Insta Handles': handles})
df
# Out:
#              Insta Handles
# 0              @jonwatts88
# 1    @ellie.eatseverything
# 2          @recipebreakout
# 3        @papamikeskitchen
# 4            @zenaskitchen
# ..                     ...
# 375         @thehungryseed
# 376  @twolittlesandwhiches
# 377         @ellacartefood
# 378            @sophiehyam
# 379           @supercooker
#
# [380 rows x 1 columns]

# %%
df.to_csv('Linkedin URLS by Keyword.csv')
