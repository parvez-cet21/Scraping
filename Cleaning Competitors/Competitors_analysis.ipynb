# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Competitors.csv',index_col='Unnamed: 0')

# %%
df.head()
# Out:
#        Company_Name  No_GoogleReviews  No_TrustPilotReviews  Google_Rating  \
# 0            Whissh                11                    24            5.0
# 1      IVS CLEANING                32                    15            5.0
# 2     Chores & Paws                 8                    12            5.0
# 3  Lavinia Cleaning                 2                     0            5.0
# 4   Better Call Moe                78                     0            5.0
#
#    TrustPilot_Rating                             Website
# 0                4.7               https://whissh.co.uk/
# 1                4.5      https://www.ivscleaning.co.uk/
# 2                3.9  https://www.choresandpawsintl.com/
# 3                0.0       https://www.lavinia.cleaning/
# 4                0.0      https://www.bettercallmoe.com/

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 48
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company_Name          49 non-null     object
#  1   No_GoogleReviews      49 non-null     int64
#  2   No_TrustPilotReviews  49 non-null     int64
#  3   Google_Rating         49 non-null     float64
#  4   TrustPilot_Rating     49 non-null     float64
#  5   Website               49 non-null     object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 2.7+ KB

# %%
df1 = df.sort_values(['No_GoogleReviews'],ascending=False)
print(' ***************    Top 20 Competitors by Number of Google Review   ***************')
df1.head(20)
# Out:
#  ***************    Top 20 Competitors by Number of Google Review   ***************
#                          Company_Name  No_GoogleReviews  No_TrustPilotReviews  \
# 44                              handy           3673569                 15427
# 8                           housekeep            369159                  4275
# 12  Glimmr: House and Office Cleaners              2500                    32
# 40                 Fantastic Cleaners              2373                 18605
# 43   The Happy House Cleaning Service               521                   278
# 7                    Cleaning Express               494                   222
# 27                               Neat               473                     0
# 11                           Anyclean               287                   299
# 34                    Go For Cleaning               252                     0
# 36                               eMop               251                   176
# ...

# %%
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{v:d}'.format(v=val)
    return my_autopct

# %%
df1.No_GoogleReviews[:10].values.tolist()
# Out:
# [3673569, 369159, 2500, 2373, 521, 494, 473, 287, 252, 251]

# %%
values_by_Reviews = df1.No_GoogleReviews[:10].values.tolist()

# %%
ax = sns.plot(x= "Company_Name" ,data=df1,order=df1.No_GoogleReviews.iloc[:10].index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-78575cc07a3c> in <module>
# ----> 1 ax = sns.plot(x= "Company_Name" ,data=df1,order=df1.No_GoogleReviews.iloc[:10].index)
#
# AttributeError: module 'seaborn' has no attribute 'plot'

# %%
df1.plot(kind='bar',title='Top 10 Competitors with highest number of reviews')
# Out:
# <AxesSubplot:title={'center':'Top 10 Competitors with highest number of reviews'}>

# %%
df2 = df.sort_values(['No_TrustPilotReviews'],ascending=False)
print(' ***************    Top 20 Competitors by Number of TrustPilot Reviews   ***************')
df2.head(20)
# Out:
#  ***************    Top 20 Competitors by Number of TrustPilot Reviews   ***************
#                          Company_Name  No_GoogleReviews  No_TrustPilotReviews  \
# 40                 Fantastic Cleaners              2373                 18605
# 44                              handy           3673569                 15427
# 8                           housekeep            369159                  4275
# 46                         Maid2Clean                 0                  3413
# 41                         MOLLY MAID                36                  3314
# 42                    Tenancy Cleaner               141                   505
# 31                          Miss Maid               137                   486
# 11                           Anyclean               287                   299
# 43   The Happy House Cleaning Service               521                   278
# 7                    Cleaning Express               494                   222
# ...

# %%
df1 = df.sort_values(['Google_Rating'],ascending=False)

print(' ***************    Top 10 Competitors by Google/Own_Site Rating   ***************')
df1.head(10)
# Out:
#  ***************    Top 10 Competitors by Google/Own_Site Rating   ***************
#                   Company_Name  No_GoogleReviews  No_TrustPilotReviews  \
# 0                       Whissh                11                    24
# 2                Chores & Paws                 8                    12
# 3             Lavinia Cleaning                 2                     0
# 4              Better Call Moe                78                     0
# 5               Quick Cleaning                 9                     0
# 6        Iva Cleaning Services                26                     0
# 1                 IVS CLEANING                32                    15
# 7             Cleaning Express               494                   222
# 8                    housekeep            369159                  4275
# 9  Wimbledon Cleaning Services                61                     4
#
#    Google_Rating  TrustPilot_Rating  \
# 0            5.0                4.7
# ...

# %%
df1 = df.sort_values(['TrustPilot_Rating'],ascending=False)

print(' ***************    Top 10 Competitors by TrustPilot Rating   ***************')
df1.head(10)
# Out:
#  ***************    Top 10 Competitors by TrustPilot Rating   ***************
#           Company_Name  No_GoogleReviews  No_TrustPilotReviews  Google_Rating  \
# 7     Cleaning Express               494                   222            4.9
# 11            Anyclean               287                   299            4.7
# 0               Whissh                11                    24            5.0
# 35          Fast Klean               127                    54            4.1
# 21       GET SET CLEAN                17                    74            4.5
# 46          Maid2Clean                 0                  3413            0.0
# 1         IVS CLEANING                32                    15            5.0
# 40  Fantastic Cleaners              2373                 18605            4.0
# 8            housekeep            369159                  4275            4.9
# 31           Miss Maid               137                   486            4.3
#
# ...

# %%
tpd['Company_Name'] = df1.Company_Name
tpd['TrustPilot_Rating'] = df1['TrustPilot_Rating'].head(10)

tpd_values = df1.TrustPilot_Rating.head(10).tolist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-8ab8f011de25> in <module>
# ----> 1 tpd['Company_Name'] = df1.Company_Name
#       2 tpd['TrustPilot_Rating'] = df1['TrustPilot_Rating'].head(10)
#       3
#       4 tpd_values = df1.TrustPilot_Rating.head(10).tolist()
#
# TypeError: list indices must be integers or slices, not str

# %%
tpd.plot(kind='pie',title='Top 10 Areas for Cleaners job by Gumtree Job Portal',autopct=make_autopct(tpd_values))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-a1e67498b458> in <module>
# ----> 1 tpd.plot(kind='pie',title='Top 10 Areas for Cleaners job by Gumtree Job Portal',autopct=make_autopct(tpd_values))
#
# AttributeError: 'list' object has no attribute 'plot'
